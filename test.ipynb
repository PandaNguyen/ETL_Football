# %%
from soccerdata import FBref
import soccerdata as sd
# Out:
# [11/10/25 19:07:16] INFO     No custom team name replacements found. You can configure these in       ]8;id=891914;file:///mnt/h/ETL_footbal/venv_linux/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=846530;file:///mnt/h/ETL_footbal/venv_linux/lib/python3.10/site-packages/soccerdata/_config.py#91\91]8;;\
#                              /home/msi/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=235373;file:///mnt/h/ETL_footbal/venv_linux/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=161401;file:///mnt/h/ETL_footbal/venv_linux/lib/python3.10/site-packages/soccerdata/_config.py#197\197]8;;\
#                              /home/msi/soccerdata/config/league_dict.json.
