# %%
import soccerdata as sd

# %%
understat = sd.Understat(leagues="ENG-Premier League",seasons=['1920','2021','2122','2223','2324','2425'])
player = understat.read_player_season_stats()
player_season_stats = df.player
# Out:
# [11/11/25 00:53:05] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\Understat          ]8;id=907632;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=875352;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 understat = sd.Understat(leagues="ENG-Premier League",seasons=['1920','2021','2122','2223','2324','2425'])
# ----> 2 player = understat.read_player_season_stats()
#       3 player_season_stats = df.player
#
# ...

# %%
fbref = sd.FBref(leagues="ENG-Premier League",seasons=['2425'])
play = fbref.read_player_match_stats()
play.head(5)
# Out:
# [11/11/25 00:57:47] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\FBref              ]8;id=482888;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=360815;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\
#                     WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\fbref.py:165: FutureWarning: The behavior of DataFrame
#                              concatenation with empty or all-NA entries is deprecated. In a future
# ...
