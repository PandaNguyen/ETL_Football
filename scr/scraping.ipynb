# %%
import soccerdata as sd
# Out:
# [11/12/25 20:52:56] INFO     No custom team name replacements found. You can configure these in       ]8;id=943005;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=996300;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\Admin\soccerdata\config\teamname_replacements.json.
# ...

# %%
understat = sd.Understat(leagues="ENG-Premier League",seasons=['1920','2021','2122','2223','2324','2425'])
player = understat.read_player_season_stats()
player
# Out:
# [11/12/25 19:42:04] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\Understat          ]8;id=135044;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=765470;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\
#                     WARNING  C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:112
#                              3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s
#                              occerdata\_common.py:145: UserWarning: Season id "2021" is ambiguous:
#                              interpreting as "20-21"
#                                warnings.warn(msg, stacklevel=1)
# ...

# %%
# fbref = sd.FBref(leagues="ENG-Premier League",seasons=['2425'])
# play = fbref.read_player_match_stats()
# play.head(5)

# %%
# import soccerdata as sd
# import pandas as pd
# Out:
# [11/11/25 13:31:35] INFO     No custom team name replacements found. You can configure these in       ]8;id=497413;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=620920;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\Admin\soccerdata\config\teamname_replacements.json.
# ...

# %%
# match_history = sd.MatchHistory(leagues="ENG-Premier League",seasons=['2425'])
# game = match_history.read_games()
# game.head(5)
# Out:
# [11/11/25 13:33:13] INFO     Saving cached data to C:\Users\Admin\soccerdata\data\MatchHistory       ]8;id=624851;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=429206;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\_common.py#263\263]8;;\
# [11/11/25 13:33:16] INFO     Parsing league=E0 season=2425                                      ]8;id=176978;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\match_history.py\match_history.py]8;;\:]8;id=309849;file://C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\soccerdata\match_history.py#17\17]8;;\
# ...

# %%
import pandas as pd
from pathlib import Path

# %%
# events = sd.WhoScored(leagues="ENG-Premier League",seasons=['2021','2122','2223','2324','2425'])
# read_event = events.read_events()
# read_event_df = pd.DataFrame(read_event)
# out_path = Path("../data/WhoScored_event.csv")
# out_path.parent.mkdir(parents=True, exist_ok=True)  
# read_event_df.to_csv(out_path, index=False, encoding="utf-8")

# read_event_df.to_csv("../data/WhoScored_event.csv")
