# %%
from configparser import ConfigParser
import psycopg2
import pandas as pd
import os

# %%
def load_config(filename='database.ini', section='postgresql'):
    current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
    file_path = os.path.join(current_dir, filename)

    if not os.path.exists(file_path):
        raise Exception(f"File {file_path} not found")

    parser = ConfigParser()
    parser.read(file_path)

    config = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            config[param[0]] = param[1]
    else:
        sections = parser.sections()
        raise Exception(f"Section {section} not found in {file_path}. Available sections: {sections}")

    return config

# %%
def connect(config):
    """Kết nối tới PostgreSQL và trả về đối tượng connection"""
    conn = None
    try:
        conn = psycopg2.connect(**config)
        print("✅ Connected to PostgreSQL server.")
        return conn
    except (Exception, psycopg2.DatabaseError) as error:
        print(f"❌ Error connecting to database: {error}")
        return None

# %%
config = load_config()
conn = connect(config)
# Out:
# ✅ Connected to PostgreSQL server.

# %%
conn.autocommit = True
cursor = conn.cursor()




sql2 = '''COPY details(stadium_id,stadium_name,capacity)
FROM '..\dim_stadimum.csv'
DELIMITER ','
CSV HEADER;'''

cursor.execute(sql2)

sql3 = '''select * from details;'''
cursor.execute(sql3)
for i in cursor.fetchall():
    print(i)

conn.commit()
conn.cl
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\admin\AppData\Local\Temp\ipykernel_13472\3468396623.py:7: SyntaxWarning: invalid escape sequence '\d'
#   sql2 = '''COPY details(stadium_id,stadium_name,capacity)
# C:\Users\admin\AppData\Local\Temp\ipykernel_13472\3468396623.py:7: SyntaxWarning: invalid escape sequence '\d'
#   sql2 = '''COPY details(stadium_id,stadium_name,capacity)
# C:\Users\admin\AppData\Local\Temp\ipykernel_13472\3468396623.py:7: SyntaxWarning: invalid escape sequence '\d'
#   sql2 = '''COPY details(stadium_id,stadium_name,capacity)
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[12], line 12
#       2 cursor = conn.cursor()
#       7 sql2 = '''COPY details(stadium_id,stadium_name,capacity)
#       8 FROM '..\dim_stadimum'
#       9 DELIMITER ','
#      10 CSV HEADER;'''
# ---> 12 cursor.execute(sql2)
#      14 sql3 = '''select * from details;'''
#      15 cursor.execute(sql3)
#
# UndefinedTable: relation "details" does not exist
